# %% [markdown]
# # 条件

# %% [markdown]
# ## 1. 什么是条件

# %% [markdown]
# 如果可以被转换为布尔类型就可以是一个条件

# %% [markdown]
# ## 2. 关系表达式

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3. 逻辑表达式

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. 注意，如果一个oprand不是布尔类型，在这个运算的时候会转换为布尔类型去运算
