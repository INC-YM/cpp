# %% [markdown]
# # 算术运算

# %% [markdown]
# ## 1. 常数

# %% [markdown]
# 1. 95 表示十进制

# %% [markdown]
# 2. 0137 表示八进制

# %% [markdown]
# 3. 0x5F表示十六进制

# %% [markdown]
# ---

# %% [markdown]
# 1. 95 int

# %% [markdown]
# 2. 95u unsigned int

# %% [markdown]
# 3. 95l long

# %% [markdown]
# 4. 95ul unsigned long

# %% [markdown]
# 5. 95lu unsigned long

# %% [markdown]
# ---

# %% [markdown]
# 1. 3.14159 // 3.14159

# %% [markdown]
# 2. 6.02e23 // 6.02*10^23

# %% [markdown]
# 3. 6.02e23L long double

# %% [markdown]
# 4. 6.02323f float

# %% [markdown]
# 5. 6.02e23 double

# %% [markdown]
# ## 2.const type qualifier(类型限定)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. const表示该变量是常数，不可修改了

# %% [markdown]
# ## 3. auto（since C++11）

# %% [markdown]
# 1. auto是一个自动的类型，is a placeholder type specifier(占位符类型指定符)

# %% [markdown]
# 2. 它的类型是它初次被赋值的数的类型

# %% [markdown]
# 3.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 注意，a的类型一但定下来就不会改变。所以不会变成double，而是会去掉其小数位

# %% [markdown]
# ## 4.算术操作符

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. ~a是按位取反，这里按位是二进制的位，取反是01对调

# %% [markdown]
# ## 5. 赋值操作

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. a++和++a的区别在于一个是先取值再++，一个是先++再取值

# %% [markdown]
# 所以b是3，c是4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 6.数据类型的转换

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 只要类型不匹配就会有类型转换

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 7.除法

# %% [markdown]
# 1. 整数除法和浮点数除法 <br>
# 两个整数相除的结果不管是整数还是浮点数，都会转换为整数

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 8.distinct operations for different types

# %% [markdown]
# 1. 只有int、long、float、double四种操作

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 操作符的类型转换是怎么样的，当低位不能满足才会转高位
