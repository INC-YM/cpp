# %% [markdown]
# # goto switch

# %% [markdown]
# ## 1.go to

# %% [markdown]
# * 调到一个期望的地方（但是程序一般不推荐使用）

# %% [markdown]
# ## 2. switch

# %% [markdown]
# 1. ""注意，一般和break搭配""

# %% [markdown]
# ![image.png](attachment:image.png)
