# %% [markdown]
# # while 循环

# %% [markdown]
# ## 1.do-while loop

# %% [markdown]
# 无论条件是否成立都先做一次

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2. break

# %% [markdown]
# 跳出循环

# %% [markdown]
# ## 3. continue

# %% [markdown]
# 提前结束一次循环
